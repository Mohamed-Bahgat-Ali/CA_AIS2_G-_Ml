# %%
task = '###!!@moclew EPGTQ!!!6789'
print (task[6:18:1])
# Out:
# moclew EPGTQ

# %%
x = task[6:12:1]
y = task[13:18:1]
print(x[::-1],y)
# Out:
# welcom EPGTQ

# %%
x = task[6:12:1]
y = task[14:18:1]
print(x[::-1],y)
# Out:
# welcom PGTQ
